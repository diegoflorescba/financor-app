# %%
import pandas as pd

df  = pd.read_excel('diego (1).xlsx')

df.head()
# Out:
#                 Fechas  Inversion Inicial Prestamos      Nombre Cliente  \
# 0  2024-08-10 00:00:00                     700000.0       Sabrina Soria
# 1  2024-09-10 00:00:00                     700000.0  Antonella Da Pozzo
# 2  2024-09-10 00:00:00                    1057956.0    Nicolas Ghibaudo
# 3  2024-11-10 00:00:00                    1221289.0      Pablo Villagra
# 4  2024-12-10 00:00:00                    1671198.6          2 clientes
#
#    Dni Cliente  Devolucion Cliente Reinversion Intereses  2024-09-01 00:00:00  \
# 0   35676162.0                              1.836002e+06        153000.166667
# 1   35055585.0                              1.229732e+06                  NaN
# 2   32442152.0                              2.962277e+06                  NaN
# 3   41264818.0                              2.198320e+06                  NaN
# 4          NaN                              4.383320e+06                  NaN
#
# ...

# %%
df.columns
# Out:
# Index([                                  'Fechas',
#                     'Inversion Inicial Prestamos',
#                                  'Nombre Cliente',
#                                     'Dni Cliente',
#        'Devolucion Cliente Reinversion Intereses',
#                               2024-09-01 00:00:00,
#                               2024-10-01 00:00:00,
#                               2024-11-01 00:00:00,
#                               2024-12-01 00:00:00,
#                               2025-01-01 00:00:00,
#                               2025-02-01 00:00:00,
#                               2025-03-01 00:00:00,
#                               2025-04-01 00:00:00,
#                               2025-05-01 00:00:00,
#                               2025-06-01 00:00:00,
#                               2025-07-01 00:00:00,
#                               2025-08-01 00:00:00,
#                               2025-09-01 00:00:00,
# ...
